# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: Brown; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Road Traffic Accidents
# Road Traffic Accident Dataset of Addis Ababa City
#     </p>

# %% [markdown]
# <h3 align="center" style="font-size: 35px; color: #800080; font-family: Georgia;">
#     <span style="color: #008080;"> Author:</span>
#     <span style="color: black;">Rahul Kumar .📄🖋️</span>
# </h3>

# %% [markdown]
# ![Road-accident-analysis.jpg](attachment:Road-accident-analysis.jpg)

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: #FFFAF3; font-size:100%; text-align:left">
#
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
#
#
# <b>  Problem Statement:</b><br>
#
# 1.Problem Statement:
# The problem is to analyze and understand road traffic accidents using the provided dataset. The goal is to perform an exploratory data analysis (EDA) to identify patterns, factors, and trends that contribute to accidents and their severity. By gaining insights from the data, the project aims to formulate evidence-based recommendations to enhance road safety and reduce the number of accidents and casualties.<br>
#     <br>
#
#
# <b>Project Objective:-</b>
#
#
# * The primary objective of the project is to conduct an EDA on the road traffic accidents dataset and extract meaningful insights. The specific objectives are as follows:
#
# Identify key risk factors: Determine the demographic and driving-related factors that are associated with a higher likelihood of accidents.
#
# 1. Assess accident severity: Analyze the casualty severity and factors influencing the outcome of accidents.
#
# 2. Investigate vehicle defects: Examine the role of vehicle defects in contributing to accidents.
#
# 3 .Explore road conditions: Understand the impact of road surface types and conditions on accident occurrence.
#
# 4. Analyze light and weather conditions: Investigate how light and weather conditions affect accident rates.
#
# 5.Examine collision types and vehicle movement: Study the types of collisions and vehicle movements leading to accidents.
#
# 6. Determine common accident causes: Identify the most frequent causes of accidents in the dataset.<br>
# <br>
#
# <b>  Project Overview:</b><br>
#
# The project will involve the following steps:
#
# 1. Data Collection: Obtain the road traffic accidents dataset containing various attributes related to accidents, drivers, vehicles, road conditions, casualties, and more.
#
# 2. Data Preprocessing: Clean the dataset by handling missing values, removing duplicates, and converting data into appropriate formats.
#
# 3. Exploratory Data Analysis (EDA): Conduct a comprehensive EDA to analyze the distribution and relationships between different variables. Visualizations, descriptive statistics, and correlation analysis will be utilized to gain insights into accident patterns.
#
# 4. Key Findings: Summarize and interpret the key findings from the EDA, highlighting the significant factors contributing to accidents and their severity.
#
# 5. Recommendations: Based on the analysis, formulate evidence-based recommendations and strategies to improve road safety and mitigate the identified risk factors.
#
# 6. Conclusion: Sum up the results and emphasize the importance of data-driven decision-making in enhancing road safety.
#
# 7. By performing this EDA, the project aims to provide valuable insights to relevant stakeholders, such as transportation authorities, policymakers, and law enforcement, to take proactive measures in reducing road accidents and making roads safer for everyone.<br></div>

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: Brown; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Loading Library
#     </p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/user/OneDrive/Desktop/RTA Dataset.csv")
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: Brown; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Basic Understanding of Data

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * There are total **32 Attributes/columns** available in the dataset.
# * There are total **12316 Records/Rows** available in the dataset.

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Generating Basic Information about Data</p>

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * There are  **2 numerical Feature** available in the dataset.
# * There are total **30 Categorical Feautures available in the dataset.**

# %% [markdown]
# ### Checking Missing_values

# %%
df1 = (df.isnull().sum()[df.isnull().sum()>0]).to_frame().rename(columns={0:"Number of Missing values"})
df1["% of Missing Values"] = round((100*df.isnull().sum()[df.isnull().sum()>0]/len(df)),2)
df1
# Out:
#                          Number of Missing values  % of Missing Values
# Educational_level                             741                 6.02
# Vehicle_driver_relation                       579                 4.70
# Driving_experience                            829                 6.73
# Type_of_vehicle                               950                 7.71
# Owner_of_vehicle                              482                 3.91
# Service_year_of_vehicle                      3928                31.89
# Defect_of_vehicle                            4427                35.95
# Area_accident_occured                         239                 1.94
# Lanes_or_Medians                              385                 3.13
# Road_allignment                               142                 1.15
# Types_of_Junction                             887                 7.20
# Road_surface_type                             172                 1.40
# ...

# %% [markdown]
# ### Duplicacy

# %%
print(f'Check Duplicates values:({df.duplicated().sum()}),({100*df.duplicated().sum()/len(df)})%')
# Out:
# Check Duplicates values:(0),(0.0)%

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * Max number of Missing values are in  **Service_year_of_vehicle----[3928] ,Defect_of_vehicle---[4427]** and Work_of_casuality[3198].
#  .we can remove this features. these things not relatable with accident.

# %% [markdown]
# ### Statistics Summary of Data

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### showing Numerical Features

# %%
num_df=df.select_dtypes(include="int")

# %% [markdown]
# ### Showing Categorical Features

# %%
cat_df=df.select_dtypes(include="O")

# %% [markdown]
# ### Checking Unique Values of Categorical Attributes.

# %%
for i in cat_df:
    print("Categorical Unique Values",df[i].unique())
    print("-"*127)
# Out:
# Categorical Unique Values ['17:02:00' '1:06:00' '14:15:00' ... '7:24:00' '19:18:00' '2:47:00']
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values ['Male' 'Female' 'Unknown']
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values ['Above high school' 'Junior high school' nan 'Elementary school'
# ...

# %%
for i in cat_df:
    print("Categorical Unique Values",df[i].value_counts())
    print("-"*127)
# Out:
# Categorical Unique Values 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 2:47:00       1
# Name: Time, Length: 1074, dtype: int64
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: Day_of_week, dtype: int64
# -------------------------------------------------------------------------------------------------------------------------------
# Categorical Unique Values 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: Age_band_of_driver, dtype: int64
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Make Things Easy:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .The value set of the categorical attributes is complete and easy to understand.
# * So we do not need to perform preprocessing steps for these attributes.**

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Data Wrangling</p>

# %% [markdown]
# ### Cleaning out Numerical Features

# %%
for col in num_df:
    print(num_df.isnull().sum())
# Out:
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# dtype: int64
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Make Things Easy:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .As you can Observe tha there is no Missing value in Numerical Features

# %% [markdown]
# ## Checking for valid/useful numerical features and removing the rest

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Important Note:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .Lets check out whether we need this numerical columns for our end result and make a decision to keep the features or remove it (If they are not necessary)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .We really may need "Number_of_vehicles_involved" because that might be lead to severity of accident (for Example: If number of vehicles is 2 and If lorry and bike collided, then the severity of bike rider is severe, elif bike and bike slight injury, and so on.. cases).
#
#
# * .We may or may not need the "Number_of_vehicles_involved", but there is a 1 supporting case, so this may be a useful feature as data cannot be lost if there is a slight chance of dependency.
#
#
# * .Coming to "Number_of_casualities", we really dont consider the number of patients. As we are aiming for severity of accident. So, we can drop the "Number_of_casualities" column.

# %%
df.drop(columns=["Number_of_casualties"],inplace=True)

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Dealing With Categorical Features</p>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Approaching Way:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * we have 30 Categorical Feautures.
# * 96% of is Categorical.
# * Need to Check which features are useful.
# * Treat missing values for useful features.
# * Get the insights with the associated data.

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Take a Decision on categorical feature wheather is useful or not:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .Observing useful features
#
# As from the data, we are classifying the severity of accident happened.
# 1. So, we really dont need the **Time** of particular instance. So, they can be left out.
# 2. **Age_band_of_driver** really would be an important feature, as the age signifes the immunity of patient. If the patient is older human (>50 or >60), his immunity levels are not so high so the injuries/recovering wont happen so easily. So, we can consider this.
#
# 3. Sex_of_driver, can be considered.
#
# 4. **Educational_level** doesn't really matter, while we are focussing on accident severity.
# 5. **Vehicle_driver_relation** too doesnt matter, as we dont need whether he is a owner of it or not.
#
# 6. **Driving_experience** it may be useful, so we can consider
#
# 7. **Type_of_vehicle** it may be useful, suppose if it is a lorry, we can try to conclude the severity of accident.
#
# 8. **Owner_of_vehicle** does not relate to accident.
#
# 9. **Service_year_of_vehicle**, this feature can be helpful as it specifies the condition of vehicle.
#
# 10. **Defect_of_vehicle**, can be considered for the condition
#
# 11. **Area_accident_occured**, dont really matter the severity really depends on collision of two/three vehicles or other irrespective of place.
#
# 12. Road_alignment, can be considered.
#
# 13. Types_of_junction, can be considered.
#
# 14. **Road_surface_type**, may be helpful in resulting of severity.
# 15. **Road_surface_conditions**, can be considered like "Road_surface_type".
#
# 16. **Light_conditions**, can be considered because this may result in accidents.
#
# 17. **Weather_conditions**, can be considered.
#
# 18. **Type_of_collision**, can be considered  this feature shows you how massivie collision between two vehicle or more vehicle.
#
# 19. **Vehilce_movement**, may be helpful.
#
# 20. **Causalty_class**, can be dropped.
#
# 21. **Sex_of_casualty**, can be dropped because we classifying the severity of Accident. At a point we consider for EDA[ exploratory data analysis]. i'll drop it after visualization . Here i can show you which gender has more casualty.
#
# 22. **Age_band_of_casulity**, can be considered.
#
# 23. **Casuality_severity**, can be considered.
#
# 24. **Work_of_casuality**, can be dropped as we dont need any inferences from the patient's work.
#
# 25. **Fitness_of_casuality**, can be considered.
#
# 26. **Pedestrian_movement**, can be dropped.
#
# 27. **Cause_of_accident**, can be considered.

# %%
cat_df.drop(columns=["Time","Day_of_week","Educational_level","Vehicle_driver_relation","Owner_of_vehicle","Area_accident_occured","Casualty_class",
    "Work_of_casuality","Work_of_casuality","Pedestrian_movement","Lanes_or_Medians"],inplace=True)

# %%
cat_df.shape
# Out:
# (12316, 20)

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Approaching Way:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * we have 21 useful Feautures.

# %% [markdown]
# #### Age_band_of_driver

# %%
cat_df["Age_band_of_driver"].value_counts()
# Out:
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: Age_band_of_driver, dtype: int64

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation :</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * .There is 999 Unknown value in **Age_band_of_driver**. we have to give them correct age criteria by campare with vairous Features

# %%
cat_df[cat_df["Age_band_of_driver"]=="Unknown"]
# Out:
#       Age_band_of_driver Sex_of_driver Driving_experience    Type_of_vehicle  \
# 64               Unknown        Female             5-10yr  Public (12 seats)
# 118              Unknown        Female         Above 10yr         Automobile
# 155              Unknown        Female              2-5yr     Lorry (11?40Q)
# 186              Unknown        Female          Below 1yr       Stationwagen
# 198              Unknown        Female             5-10yr   Pick up upto 10Q
# ...                  ...           ...                ...                ...
# 12216            Unknown          Male         Above 10yr         Automobile
# 12241            Unknown          Male              2-5yr    Lorry (41?100Q)
# 12251            Unknown          Male         Above 10yr                NaN
# 12252            Unknown          Male         Above 10yr         Automobile
# 12312            Unknown          Male             5-10yr         Automobile
#
# ...

# %%
cat_df["Age_band_of_casualty"].value_counts()
# Out:
# na          4443
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: Age_band_of_casualty, dtype: int64

# %%
pd.crosstab(cat_df["Age_band_of_driver"],cat_df["Age_band_of_casualty"])
# Out:
# Age_band_of_casualty  18-30  31-50   5  Over 51  Under 18    na
# Age_band_of_driver
# 18-30                  1123    876  90      331       369  1482
# 31-50                  1015    773  72      336       364  1527
# Over 51                 398    306  24      130       135   592
# Under 18                220    163  25       68        56   293
# Unknown                 389    337  33      129       111   549

# %%
pd.crosstab(cat_df["Age_band_of_driver"],cat_df["Driving_experience"])
# Out:
# Driving_experience  1-2yr  2-5yr  5-10yr  Above 10yr  Below 1yr  No Licence  \
# Age_band_of_driver
# 18-30                 583    908    1136         772        517          44
# 31-50                 584    869    1138         769        416          40
# Over 51               257    330     418         291        155          13
# Under 18              102    187     247         134         96           6
# Unknown               230    319     424         296        158          15
#
# Driving_experience  unknown
# Age_band_of_driver
# 18-30                    12
# 31-50                     9
# Over 51                   4
# Under 18                  3
# Unknown                   5

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Assumtion by using Feature:</font></h3>
# <div style="font-family:Georgia;background-color:'Orange'; font-color:'black',padding:30px; font-size:17px">
#
# * we got the feature where i can campare with **Driving_experience**. on basis on experience i can assume age range.

# %%
for i , j ,k in zip(cat_df["Age_band_of_driver"],cat_df["Driving_experience"],cat_df.index.tolist()):
    if i=="Unknown" and j=="1-2yr":
        cat_df.loc[k,"Age_band_of_driver"]="18-30"
    elif i=="Unknown" and j=="2-5yr":
        cat_df.loc[k,"Age_band_of_driver"]="31-50"
    elif i=="Unknown" and i=="Above 10yr":
        cat_df.loc[k,"Age_band_of_driver"]="over 51"

# %%
cat_df["Age_band_of_driver"].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=Orange>💬 Observation :</font></h3>
#
# 1. There is No Missing Value.<br></div>

# %% [markdown]
# #### Feature Sex_of_Driver

# %%
cat_df["Sex_of_driver"].value_counts()
# Out:
# Male       11437
# Female       701
# Unknown      178
# Name: Sex_of_driver, dtype: int64

# %%
cat_df["Sex_of_driver"].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=Orange>💬 Observation :</font></h3>
#
# 1. There is No Missing Value.<br></div>

# %% [markdown]
# #### Feature Driving_experience

# %%
cat_df['Driving_experience'].value_counts()
# Out:
# 5-10yr        3363
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: Driving_experience, dtype: int64

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=Orange>💬 Observation :</font></h3>
#
# 1. There is 33 Unknown values in this Feature. we can neglect .<br></div>

# %%
cat_df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
cat_df['Driving_experience'].isnull().sum()
# Out:
# 829

# %%
cat_df['Driving_experience'].fillna(cat_df['Driving_experience'].mode()[0],inplace=True)

# %%
cat_df['Driving_experience'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Feature  Type_of_vehicle

# %%
cat_df['Type_of_vehicle'].value_counts()
# Out:
# Automobile              3205
# Lorry (41?100Q)         2186
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Special vehicle           84
# Ridden horse              76
# Turbo                     46
# Bajaj                     29
# Bicycle                   21
# Name: Type_of_vehicle, dtype: int64

# %%
cat_df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * The details which are mention **Type _of_vehicle** not giving such  type of any information . so  i rename details of data

# %%
cat_df["Type_of_vehicle"] = cat_df["Type_of_vehicle"].replace({"Public (> 45 seats)":"Mini Bus","Lorry (41?100Q)":"Lorry",
                                                              "Public (13?45 seats)":"Bus","Public (12 seats)":"Van",
                                                              "Pick up upto 10Q":"mini van","Stationwagen":"Wagen"})

# %%
cat_df['Type_of_vehicle']
# Out:
# 0            Automobile
# 1              Mini Bus
# 2                 Lorry
# 3              Mini Bus
# 4                   NaN
#               ...
# 12311    Lorry (11?40Q)
# 12312        Automobile
# 12313             Bajaj
# 12314             Lorry
# 12315             Other
# Name: Type_of_vehicle, Length: 12316, dtype: object

# %%
cat_df['Type_of_vehicle'].isnull().sum()
# Out:
# 950

# %%
cat_df['Type_of_vehicle'].fillna(cat_df['Type_of_vehicle'].mode()[0],inplace=True)

# %%
cat_df['Type_of_vehicle'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=Orange>💬 Observation :</font></h3>
#
# 1. There is No Missing Value.<br></div>

# %% [markdown]
# ####  Feature Road_allignment

# %%
cat_df["Road_allignment"].value_counts()
# Out:
# Tangent road with flat terrain                   10459
# Tangent road with mild grade and flat terrain      501
# Steep grade downward with mountainous terrain      429
# Tangent road with mountainous terrain and          396
# Gentle horizontal curve                            163
# Escarpments                                        113
# Sharp reverse curve                                 57
# Tangent road with rolling terrain                   37
# Steep grade upward with mountainous terrain         19
# Name: Road_allignment, dtype: int64

# %%
cat_df["Road_allignment"].isnull().sum()
# Out:
# 142

# %%
cat_df["Road_allignment"].fillna(cat_df["Road_allignment"].mode()[0],inplace=True)

# %%
cat_df["Road_allignment"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ####  Types_of_Junction

# %%
cat_df['Types_of_Junction'].value_counts()
# Out:
# Y Shape        4543
# No junction    3837
# Crossing       2177
# Other           445
# Unknown         191
# O Shape         164
# T Shape          60
# X Shape          12
# Name: Types_of_Junction, dtype: int64

# %%
cat_df["Types_of_Junction"] = cat_df["Types_of_Junction"].replace("Unknown","No junction")
cat_df['Types_of_Junction'].value_counts()
# Out:
# Y Shape        4543
# No junction    4028
# Crossing       2177
# Other           445
# O Shape         164
# T Shape          60
# X Shape          12
# Name: Types_of_Junction, dtype: int64

# %%
cat_df['Types_of_Junction'].isnull().sum()
# Out:
# 887

# %%
cat_df['Types_of_Junction'].fillna(cat_df['Types_of_Junction'].mode()[0],inplace=True)

# %%
cat_df['Types_of_Junction'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=Orange>💬 Observation :</font></h3>
#
# 1. Now there is No Missing Value.<br></div>

# %%
cat_df["Road_surface_type"].value_counts()
# Out:
# Asphalt roads                       11296
# Earth roads                           358
# Gravel roads                          242
# Other                                 167
# Asphalt roads with some distress       81
# Name: Road_surface_type, dtype: int64

# %% [markdown]
# #### Road_surface_type

# %%
cat_df["Road_surface_type"].unique()
# Out:
# array(['Asphalt roads', 'Earth roads', nan,
#        'Asphalt roads with some distress', 'Gravel roads', 'Other'],
#       dtype=object)

# %%
cat_df["Road_surface_type"].isnull().sum()
# Out:
# 172

# %%
cat_df["Road_surface_type"].fillna(cat_df["Road_surface_type"].mode()[0],inplace=True)

# %%
cat_df["Road_surface_type"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Road_surface_conditions

# %%
cat_df["Road_surface_conditions"].value_counts()
# Out:
# Dry                     9340
# Wet or damp             2904
# Snow                      70
# Flood over 3cm. deep       2
# Name: Road_surface_conditions, dtype: int64

# %%
cat_df['Road_surface_conditions'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Light_conditions

# %%
cat_df['Light_conditions'].value_counts()
# Out:
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: Light_conditions, dtype: int64

# %%
cat_df['Light_conditions'].unique()
# Out:
# array(['Daylight', 'Darkness - lights lit', 'Darkness - no lighting',
#        'Darkness - lights unlit'], dtype=object)

# %%
cat_df['Light_conditions'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Weather_conditions

# %%
cat_df["Weather_conditions"].value_counts()
# Out:
# Normal               10063
# Raining               1331
# Other                  296
# Unknown                292
# Cloudy                 125
# Windy                   98
# Snow                    61
# Raining and Windy       40
# Fog or mist             10
# Name: Weather_conditions, dtype: int64

# %%
cat_df["Weather_conditions"].unique()
# Out:
# array(['Normal', 'Raining', 'Raining and Windy', 'Cloudy', 'Other',
#        'Windy', 'Snow', 'Unknown', 'Fog or mist'], dtype=object)

# %%
cat_df["Weather_conditions"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Type_of_collision

# %%
cat_df["Type_of_collision"].value_counts()
# Out:
# Vehicle with vehicle collision             8774
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# Unknown                                      14
# With Train                                    9
# Name: Type_of_collision, dtype: int64

# %%
cat_df["Type_of_collision"].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
cat_df["Type_of_collision"].isnull().sum()
# Out:
# 155

# %%
cat_df["Type_of_collision"].fillna(cat_df["Type_of_collision"].mode()[0],inplace=True)

# %% [markdown]
# #### Vehicle_movement

# %%
cat_df['Vehicle_movement'].value_counts()
# Out:
# Going straight         8158
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Unknown                  88
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: Vehicle_movement, dtype: int64

# %%
cat_df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
#cat_df.loc[(cat_df["Age_band_of_casualty"]='31-50'),"Sex_of_casualty"]="Male"

# %% [markdown]
# #### Service_year_of_vehicle

# %%
cat_df["Service_year_of_vehicle"].value_counts()
# Out:
# Unknown       2883
# 2-5yrs        1792
# Above 10yr    1324
# 5-10yrs       1280
# 1-2yr          827
# Below 1yr      282
# Name: Service_year_of_vehicle, dtype: int64

# %%
cat_df["Service_year_of_vehicle"].unique()
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
cat_df["Service_year_of_vehicle"].isnull().sum()
# Out:
# 3928

# %%
cat_df["Service_year_of_vehicle"].fillna(cat_df["Service_year_of_vehicle"].mode()[0],inplace=True)

# %%
cat_df["Service_year_of_vehicle"].isnull().sum()
# Out:
# 0

# %%
cat_df["Service_year_of_vehicle"].value_counts()
# Out:
# Unknown       6811
# 2-5yrs        1792
# Above 10yr    1324
# 5-10yrs       1280
# 1-2yr          827
# Below 1yr      282
# Name: Service_year_of_vehicle, dtype: int64

# %%
pd.crosstab(cat_df["Service_year_of_vehicle"],cat_df["Driving_experience"])
# Out:
# Driving_experience       1-2yr  2-5yr  5-10yr  Above 10yr  Below 1yr  \
# Service_year_of_vehicle
# 1-2yr                      140    160     290         132         94
# 2-5yrs                     252    397     613         303        205
# 5-10yrs                    151    278     411         286        133
# Above 10yr                 161    260     499         268        124
# Below 1yr                   49     63      76          57         32
# Unknown                   1003   1455    2303        1216        754
#
# Driving_experience       No Licence  unknown
# Service_year_of_vehicle
# 1-2yr                            10        1
# 2-5yrs                           19        3
# 5-10yrs                          16        5
# Above 10yr                        8        4
# Below 1yr                         4        1
# Unknown                          61       19

# %%
for i , j,k in zip(cat_df["Service_year_of_vehicle"],cat_df["Driving_experience"],cat_df.index.tolist()):
    if i=="Unknown" and j=="1-2yr":
        cat_df.loc[k,"Service_year_of_vehicle"]="1-2yr"
    elif i=="Unknown" and j=="2-5yr":
        cat_df.loc[k,"Service_year_of_vehicle"]= "2-5yrs"
    elif i=="Unknown" and j=="5-10yr":
        cat_df.loc[k,"Service_year_of_vehicle"]="5-10yrs"
    elif i=="Unknown" and j=="Above 10yr":
        cat_df.loc[k,"Service_year_of_vehicle"]="Above 10yr"
    elif i=="Unknown" and j=="Below 1yr":
        cat_df.loc[k,"Service_year_of_vehicle"]= "Below 1yr"
    elif i=="Unknown" and j=="No Licence":
        cat_df.loc[k,"Service_year_of_vehicle"]= "No Licence"

# %%
cat_df['Fitness_of_casuality'].value_counts()
# Out:
# Normal          9608
# NormalNormal      19
# Deaf              18
# Other             18
# Blind             18
# Name: Fitness_of_casuality, dtype: int64

# %%
cat_df['Fitness_of_casuality'].replace("NormalNormal","Normal",inplace=True)

# %%
cat_df["Fitness_of_casuality"].isnull().sum()
# Out:
# 2635

# %%
cat_df["Fitness_of_casuality"].fillna(cat_df["Fitness_of_casuality"].mode()[0],inplace=True)

# %%
cat_df['Cause_of_accident'].value_counts()
# Out:
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          25
# Name: Cause_of_accident, dtype: int64

# %%
cat_df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
cat_df['Cause_of_accident'].isnull().sum()
# Out:
# 0

# %%
cat_df['Accident_severity'].value_counts()
# Out:
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: Accident_severity, dtype: int64

# %%
cat_df['Accident_severity'].unique()
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %%
cat_df['Accident_severity'].isnull().sum()
# Out:
# 0

# %%
cat_df['Defect_of_vehicle'].value_counts()
# Out:
# No defect    7777
# 7              76
# 5              36
# Name: Defect_of_vehicle, dtype: int64

# %%
cat_df['Defect_of_vehicle'].unique()
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
cat_df['Defect_of_vehicle'].isnull().sum()
# Out:
# 4427

# %%
cat_df['Defect_of_vehicle'].fillna(cat_df['Defect_of_vehicle'].mode()[0],inplace=True)

# %%
cat_df['Vehicle_movement'].value_counts()
# Out:
# Going straight         8158
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Unknown                  88
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: Vehicle_movement, dtype: int64

# %%
cat_df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
cat_df['Vehicle_movement'].isnull().sum()
# Out:
# 308

# %%
cat_df['Vehicle_movement'].fillna(cat_df['Vehicle_movement'].mode()[0],inplace=True)

# %%
cat_df.head(10)
# Out:
#   Age_band_of_driver Sex_of_driver Driving_experience Type_of_vehicle  \
# 0              18-30          Male              1-2yr      Automobile
# 1              31-50          Male         Above 10yr        Mini Bus
# 2              18-30          Male              1-2yr           Lorry
# 3              18-30          Male             5-10yr        Mini Bus
# 4              18-30          Male              2-5yr      Automobile
# 5              31-50          Male             5-10yr      Automobile
# 6              18-30          Male              2-5yr      Automobile
# 7              18-30          Male              2-5yr      Automobile
# 8              18-30          Male         Above 10yr           Lorry
# 9              18-30          Male              1-2yr      Automobile
#
#   Service_year_of_vehicle Defect_of_vehicle  \
# 0              Above 10yr         No defect
# 1                 5-10yrs         No defect
# 2                   1-2yr         No defect
# ...

# %%
df2= pd.concat((cat_df,num_df),axis=1)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:orange;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> Exploratory Data Analysis.</b></div>

# %%
df2.head()
# Out:
#   Age_band_of_driver Sex_of_driver Driving_experience Type_of_vehicle  \
# 0              18-30          Male              1-2yr      Automobile
# 1              31-50          Male         Above 10yr        Mini Bus
# 2              18-30          Male              1-2yr           Lorry
# 3              18-30          Male             5-10yr        Mini Bus
# 4              18-30          Male              2-5yr      Automobile
#
#   Service_year_of_vehicle Defect_of_vehicle  \
# 0              Above 10yr         No defect
# 1                 5-10yrs         No defect
# 2                   1-2yr         No defect
# 3                 5-10yrs         No defect
# 4                 5-10yrs         No defect
#
#                                  Road_allignment Types_of_Junction  \
# 0                 Tangent road with flat terrain       No junction
# 1                 Tangent road with flat terrain       No junction
# 2                 Tangent road with flat terrain       No junction
# ...

# %%
a = df2.groupby('Cause_of_accident')['Cause_of_accident'].agg(['count'])
b  = a.sort_values(by='count',ascending=False).reset_index()
b
# Out:
#                        Cause_of_accident  count
# 0                          No distancing   2263
# 1             Changing lane to the right   1808
# 2              Changing lane to the left   1473
# 3                     Driving carelessly   1402
# 4                 No priority to vehicle   1207
# 5                        Moving Backward   1137
# 6              No priority to pedestrian    721
# 7                                  Other    456
# 8                             Overtaking    430
# 9   Driving under the influence of drugs    340
# 10                   Driving to the left    284
# 11    Getting off the vehicle improperly    197
# 12                 Driving at high speed    174
# 13                           Overturning    149
# 14                              Turnover     78
# 15                             Overspeed     61
# 16                           Overloading     59
# 17                         Drunk driving     27
# 18                      Improper parking     25
# ...

# %%
ab = b.loc[0:10,]

# %%
plt.figure(figsize=(10,4))
sns.barplot(ab['Cause_of_accident'],ab['count'])
plt.title("Graphical Representation to Probability of Top 4 Cause to Happen")
plt.xlabel("Couse of Accident")
plt.xticks(rotation="vertical");

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * There are four major Road Accident causes which are **[NO Distance , Changing lane to the right ,Changing lane to the left, Driving carelessly  ]**
# * Conditional Probability of Each Cause to Happen When Maximum (Fatal) Severity Occur .

# %%
A =df2.groupby(["Light_conditions"])["Accident_severity"].agg(["count"])
B = A.sort_values(by='count',ascending=False).reset_index()
B
# Out:
#           Light_conditions  count
# 0                 Daylight   8798
# 1    Darkness - lights lit   3286
# 2   Darkness - no lighting    192
# 3  Darkness - lights unlit     40

# %%
plt.figure(figsize=(8,4))
sns.barplot(B["Light_conditions"],B["count"])
plt.title("Max Raod Accident Severity")
plt.xlabel("Couse of Accident");

# %%
count=df2["Sex_of_driver"].value_counts()
plt.figure(figsize=(8,3))
plt.subplot(1,2,2)
ax=sns.countplot(df2["Sex_of_driver"])
ax.bar_label(ax.containers[0],fontweight="black",size=15)

plt.subplot(1,2,2)
plt.figure(figsize=(13,6))
gender = df2["Sex_of_driver"].value_counts()
plt.pie(gender, labels=gender.index,autopct="%.2f%%",textprops={"fontweight":"black","size":15},
        explode=[0,0.1,0.1],colors= ['#FF8000', '#FF9933', '#FFB366', '#FFCC99'])
plt.title("% Gender involve in Road Accident",fontweight="black",pad=15,size=18);

# %%
plt.figure(figsize=(16,5))
sns.countplot(df2["Age_band_of_driver"]);
plt.title("Age Group",fontsize=20);

# %%
sns.countplot(df["Accident_severity"])
plt.title("Accident Severity category")
# Out:
# Text(0.5, 1.0, 'Accident Severity category')

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,3,2)
sns.barplot(df2["Accident_severity"],df2["Number_of_casualties"],palette="Set2")
plt.xticks(rotation="vertical");
plt.title("number of casualties in Severity Type");

# %%
sns.barplot(df["Accident_severity"],df["Number_of_vehicles_involved"])
plt.title("Number of vehicles of involve in Accident serverity")
# Out:
# Text(0.5, 1.0, 'Number of vehicles of involve in Accident serverity')

# %%
sns.countplot(df["Type_of_vehicle"])
plt.xticks(rotation="vertical");
plt.title("Type of Vehicle");

# %%
plt.figure(figsize =(6,6))
a = (df2.loc[df2['Age_band_of_driver'] !="Unknown"].groupby('Age_band_of_driver').size()/df2["Age_band_of_driver"].count())*10022

bar_plot=a.sort_values(ascending=False).plot(kind='bar')
bar_plot.set_ylabel("Count")
bar_plot.set_xlabel("Age Band")
bar_plot.set_ylabel("Percentage Of Total Accidents")
bar_plot.set_title("Age Band And Percentage Of Accidents")
# Out:
# Text(0.5, 1.0, 'Age Band And Percentage Of Accidents')

# %% [markdown]
# ## Realtion Between Age And Severity Of Accident
# Hypothesis : Younger Drivers Commit More Accidents Than Older Drivers Due To Their Impulsiveness
# Younger Drivers Are Expected To Commit More Accidents And Crashes Compared To Older Drivers

# %%
ff = pd.crosstab(index=df2['Light_conditions'], columns=df2['Light_conditions'], margins=True)
pd.crosstab(index=df2['Light_conditions'], columns=df2['Light_conditions'], margins=True)
numOfDayLight = ff.iloc[3, 3]
numOfDayLight
numOfNightLit = ff.iloc[0, 0]

# %%
survey_data = pd.crosstab(index=df2['Accident_severity'], columns=df2['Light_conditions'], margins=True)
survey_data
numOfDayLightNS2 = survey_data.iloc[2, 3]
numOfSev2 = survey_data.iloc[2, 4]
numOfDayLightNS2
survey_data.iloc[2, 2]
survey_data
# Out:
# Light_conditions   Darkness - lights lit  Darkness - lights unlit  \
# Accident_severity
# Fatal injury                          66                        0
# Serious Injury                       465                        7
# Slight Injury                       2755                       33
# All                                 3286                       40
#
# Light_conditions   Darkness - no lighting  Daylight    All
# Accident_severity
# Fatal injury                            5        87    158
# Serious Injury                         49      1222   1743
# Slight Injury                         138      7489  10415
# All                                   192      8798  12316

# %%
A = numOfDayLightNS2 / numOfSev2
A
# Out:
# 0.7190590494479117

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Observation:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * since the mean of severity is higher in the daylight and the probability of severity is fatal happening given the accident happened in daylight accidents is very high ,thus the hypothesis is wrong.

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
Severity = df2["Accident_severity"].value_counts()
sns.barplot(x=Severity.index,y=Severity.values,palette=["#1d7874","#8B0000"])
plt.title("Severity Analysis",fontweight="black",size=18,pad=20)
for i,j in enumerate(Severity.values):
    plt.text(i,j,j, ha = "center",fontweight="black",fontsize=18)

plt.subplot(1,2,2)
plt.pie(Severity,  autopct="%.2f%%", textprops={"fontweight":"black","size":15},
        colors = ["#1d7874","#AC1F29"],explode=[0,0.1,0.1],startangle=90)
center_circle = plt.Circle((0, 0), 0.3, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
plt.title("Accident Severity",fontweight="black",size=20,pad=10)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: Brown; font-size:100%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Conclusion</p></div>

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Key-Points</font></h3>
#
#
# * **EDA Conclusion and Key Points**:
#
# Age and Driving Experience:
#
# Young and inexperienced drivers are more prone to accidents compared to older and experienced drivers.
# Young drivers need targeted road safety interventions and awareness programs.
#
# **Gender**:
#
# There might be variations in accident rates between male and female drivers.
# Understanding gender-specific accident patterns can lead to gender-specific safety measures.
#
# **Vehicle Defects**:
#
# Vehicle defects play a role in contributing to accidents.
# Regular vehicle maintenance and inspections are essential to minimize accidents caused by defects.
#
# **Road Conditions**:
#
# Different road surface types and conditions affect accident frequencies.
# Improving road conditions can have a positive impact on road safety.
#
# **Light and Weather Conditions***:
#
# Poor visibility due to low light or adverse weather conditions increases accident risk.
# Adequate street lighting and weather alerts can help prevent accidents in such conditions.
#
# **Causes of Accidents**:
#
# Identifying common causes of accidents is crucial for preventive strategies.
# Addressing major accident causes can significantly reduce accident rates.
#
# **Key Points**:
#
# 1. Young and inexperienced drivers, especially males, are at higher risk of accidents.
#
# 2. Regular vehicle maintenance is essential to prevent accidents caused by defects.
#
# 3. Poor road conditions and visibility contribute to accident occurrences.
#
# 4. Junctions with complex designs may require additional safety measures.
#
# 5. Casualty severity is influenced by multiple factors, including age and accident severity.
#
# 6. Data-driven interventions and road safety campaigns are essential for reducing accidents.
#
# 7. Overall, the EDA provides valuable insights into road traffic accidents and their contributing factors. The analysis can guide policymakers, traffic authorities, and stakeholders in formulating targeted measures to improve road safety, reduce accidents, and save lives on the roads.
#
#
# <h3 align="left"><font color=brown>📊 Recommendations</font></h3>
#
# Recommendations based on Road Traffic Accidents EDA:
#
# **Regular Vehicle Maintenance**:
#
# 1. Encourage vehicle owners to conduct regular maintenance checks and address any defects promptly.
# Promote awareness campaigns on the importance of vehicle safety and maintenance.
# Improved Road Infrastructure:
#
# 2. Identify accident-prone roads and junctions, and invest in improving their design and safety features.
# Ensure proper road signage, markings, and adequate street lighting to enhance visibility.
#
# **Weather and Light Condition Alerts**:
#
# 3. Implement weather condition alert systems to warn drivers about adverse weather conditions.
# Install smart lighting systems to adjust lighting levels based on ambient light conditions.
#
# **Safety Inspections for Vehicles and Roads**:
#
# 4. Introduce mandatory safety inspections for vehicles, especially for older vehicles, to reduce accidents caused by vehicle defects.
# 5. Conduct periodic road safety audits to identify potential hazards and road condition issues.
#
# **Focused Enforcement of Traffic Laws**:
#
# Increase law enforcement presence at accident-prone locations to deter reckless driving and enforce traffic laws.
# Implement strict penalties for traffic violations to promote adherence to road safety rules.
#
# **Public Awareness Campaigns**:
#
# Launch public awareness campaigns on road safety, targeting all road users, including pedestrians and cyclists.
# Use social media, billboards, and community outreach programs to spread road safety messages.

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Advice:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * Having less driving experience will result in more severe accidents. It is recommended to provide more training for inexperienced drivers. Furthermore, drivers with no license have the most severe accidents.thus, the hypothesis is wrong
